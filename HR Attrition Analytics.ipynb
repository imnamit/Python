# %%
pwd
# Out:
# 'C:\\Users\\IBS'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#import the data#

data = pd.read_csv('HR.csv')
data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  \
# 0                   3              0     1                      0
# 1                   6              0     1                      0
# 2                   4              0     1                      0
# 3                   5              0     1                      0
# 4                   3              0     1                      0
#
#   Departments   salary
# 0        sales     low
# 1        sales  medium
# 2        sales  medium
# ...

# %%
data.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Departments  salary
# 14994                      0      support    low
# 14995                      0      support    low
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
# satisfaction_level       14999 non-null float64
# last_evaluation          14999 non-null float64
# number_project           14999 non-null int64
# average_montly_hours     14999 non-null int64
# time_spend_company       14999 non-null int64
# Work_accident            14999 non-null int64
# left                     14999 non-null int64
# promotion_last_5years    14999 non-null int64
# Departments              14999 non-null object
# salary                   14999 non-null object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
left = data.groupby('left')
left2=data.groupby(satifaction_level).mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-872678fa4b68> in <module>()
#       1 left = data.groupby('left')
# ----> 2 left2=data.groupby(satisfaction_level).mean()
#
# NameError: name 'satisfaction_level' is not defined

# %%
left.mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
left.mean('satisfaction_level')
# Out:
# ---------------------------------------------------------------------------
# UnsupportedFunctionCall                   Traceback (most recent call last)
# <ipython-input-11-af86ad231127> in <module>()
# ----> 1 left.mean('satisfaction_level')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1302         For multiple groupings, the result index will be a MultiIndex
#    1303         """
# -> 1304         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1305         try:
#    1306             return self._cython_agg_general('mean', **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\compat\numpy\function.py in validate_groupby_func(name, args, kwargs, allowed)
#     340             "numpy operations are not valid "
#     341             "with groupby. Use .groupby(...)."
# --> 342             "{func}() instead".format(func=name)))
#     343
#     344
#
# ...

# %%
left.mean(data.satisfaction_level)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedFunctionCall                   Traceback (most recent call last)
# <ipython-input-12-4b75a60773e1> in <module>()
# ----> 1 left.mean(data.satisfaction_level)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1302         For multiple groupings, the result index will be a MultiIndex
#    1303         """
# -> 1304         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1305         try:
#    1306             return self._cython_agg_general('mean', **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\compat\numpy\function.py in validate_groupby_func(name, args, kwargs, allowed)
#     340             "numpy operations are not valid "
#     341             "with groupby. Use .groupby(...)."
# --> 342             "{func}() instead".format(func=name)))
#     343
#     344
#
# ...

# %%
#to get mean of particular one variable#
data['satisfaction_level'].mean()
# Out:
# 0.6128335222348166

# %%
left2.mean()
# Out:
# last_evaluation            0.703898
# number_project             3.834166
# average_montly_hours     198.064658
# time_spend_company         3.624835
# Work_accident              0.150618
# left                       0.195617
# promotion_last_5years      0.020855
# dtype: float64

# %%
left_count = data.groupby('left').count()
plt.bar(left_count.index.values, left_count['satisfaction_level'])
plt.xlabel('emps left org')
plt.ylabel('nos of emps')
plt.show()

# %%
num_projects = data.groupby('number_project').count()
plt.bar(num_projects.index.values, num_projects['satisfaction_level'])
plt.xlabel('nos of prjoects')
plt.ylabel('nos of emps')
plt.show()

# %%
time_spent = data.groupby('time_spe_company').count()
plt.bar(time_spent.index.values, time_spent['satisfaction_level'])
plt.xlabel('time spent')
plt.ylabel('nos of emps')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-ec91518fe61c> in <module>()
# ----> 1 time_spent = data.groupby('time_spent_company').count()
#       2 plt.bar(time_spent.index.values, time_spent['satisfaction_level'])
#       3 plt.xlabel('time spent')
#       4 plt.ylabel('nos of emps')
#       5 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ...

# %%
time_spent = data.groupby('time_spend_company').count()
plt.bar(time_spent.index.values, time_spent['satisfaction_level'])
plt.xlabel('time spent')
plt.ylabel('nos of emps')
plt.show()

# %%
#plot all grapghs in  single#
features=['number_project','time_spend_company','Work_accident','left','promotion_last_5years','Departments','salary']
fig=plt.subplots(figsize=(10,15))
for i, j in enumerate (features):
    plt.subplot(4,2,i+1)
    plt.subplots_adjust(hspace=1.0)
    sns.countplot(x=j, data=data)
    plt.xticks(rotation=90)
    plt.title('nos of emps')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-b4a8380bf537> in <module>()
#       5     plt.subplot(4,2,i+1)
#       6     plt.subplots_adjust(hspace=1.0)
# ----> 7     sns.countplot(x=j, data=data)
#       8     plt.xticks(rotation=90)
#       9     plt.title('nos of emps')
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# ...

# %%
#plot all grapghs in  single#
features=['number_project','time_spend_company','Work_accident','left','promotion_last_5years','Departments ','salary']
fig=plt.subplots(figsize=(10,15))
for i, j in enumerate (features):
    plt.subplot(4,2,i+1)
    plt.subplots_adjust(hspace=1.0)
    sns.countplot(x=j, data=data)
    plt.xticks(rotation=90)
    plt.title('nos of emps')

# %%
fig=plt.subplots(figsize=(10,15))
for i, j in enumerate (features):
    plt.subplot(4,2,i+1)
    plt.subplots_adjust(hspace=1.0)
    sns.countplot(x=j, data=data, hue='left')
    plt.xticks(rotation=90)
    plt.title('nos of emps')

# %%
import KMeans
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-0202b98bdf4c> in <module>()
# ----> 1 import KMeans
#
# ModuleNotFoundError: No module named 'KMeans'

# %%
pip.learn sklearn.cluster
# Out:
#   File "<ipython-input-34-fa6b1ee4d2f4>", line 1
#     pip.learn sklearn.cluster
#                     ^
# SyntaxError: invalid syntax

# %%
pip.install sklearn.cluster
# Out:
#   File "<ipython-input-35-6b233005affa>", line 1
#     pip.install sklearn.cluster
#                       ^
# SyntaxError: invalid syntax

# %%
from sklearn.cluster import KMeans

# %%
left_emp = data[['satisfaction_level','last_evaluation']][data.left==1]

# %%
kmeans=KMeans(n_clusters = 3, random_state = 0).fit(left_emp)
